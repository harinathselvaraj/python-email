# %%
import email, smtplib, ssl
from email import encoders
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

# %%
subject = "Harinath's test email from Python App"
sender_email = "harinathselvaraj@gmail.com"
receiver_email = "harinath.selvaraj@outlook.com"
password = input("Type your password and press enter:")
# Out:
# Type your password and press enter:*******

# %%
body = """

<html xmlns:fb='http://www.facebook.com/2008/fbml' xmlns:og='http://opengraph.org/schema/'><head>

  <meta property='og:title' content='This is email subject'>
  <!-- <meta property='fb:page_id' content='43929265776'> -->
  <meta name='viewport' content='width=device-width, initial-scale=1, maximum-scale=1'>
  <meta name='referrer' content='origin'>
  <meta http-equiv='content-type' content='text/html; charset=utf-8'>
  <meta http-equiv='x-ua-compatible' content='IE=edge'>
  <meta name='viewport' content='width=auto, initial-scale=1.0'>
  <title></title>
  <style type='text/css'>
    @media screen and (min-width: 480px) {
      .bottom-padded {
        padding-bottom: 40px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .side-padded {
        padding-left: 50px;
        padding-right: 50px;
      }

    }

    @media screen and (min-width: 480px) {
      .header-link {
        padding: 23px 0 25px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .header-link a {
        font-size: 14px;
      }

    }

    @media screen and (min-width: 480px) {
      .header-logo {
        padding-bottom: 40px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .header-logo img {
        width: 248px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .intro {
        padding-top: 36px !important;
        padding-bottom: 54px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .intro-title {
        padding-bottom: 14px !important;
        font-size: 26px !important;
        line-height: 32px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .intro-img {
        font-size: 54px !important;
        line-height: 54px !important;
        padding-bottom: 22px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .section {
        padding-bottom: 15px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .section-title {
        padding-bottom: 14px !important;
        font-size: 36px !important;
        line-height: 42px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .section-img {
        padding-bottom: 30px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .section-descr {
        padding-bottom: 12px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .section-descr p {
        margin-bottom: 16px !important;
        font-size: 15px !important;
        line-height: 23px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .btn {
        padding-left: 30px !important;
        padding-right: 30px !important;
        margin-bottom: 25px !important;
        font-size: 15px !important;
        line-height: 43px !important;
        letter-spacing: 1px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .bottom-part-wrapper {
        padding-top: 10px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .bottom-part-address {
        padding-bottom: 6px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .bottom-part-logo {
        padding-bottom: 14px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .bottom-part-descr {
        padding-bottom: 25px !important;
      }

    }

    @media screen and (min-width: 480px) {
      .social-links {
        padding-top: 10px !important;
        padding-bottom: 12px !important;
      }

    }
  </style>
  <link rel='stylesheet' href='https://us3.campaign-archive2.com/css/archivebar-desktop.css' mc:nocompile=''>
</head>

<body style='Margin:0;padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;min-width:100%;background-color:#e9f1f2;-webkit-font-smoothing:antialiased;background-image:none;background-repeat:repeat;background-position:top left;background-attachment:scroll;'>
  <center class='wrapper' style='width:100%;table-layout:fixed;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%;background-color:#e9f1f2;background-image:none;background-repeat:repeat;background-position:left top;background-attachment:scroll;'>
    <div class='webkit' style='max-width:750px;'>
      <table class='outer' align='center' border='0' cellpadding='0' cellspacing='0' width='100%' style='height:100%;border-spacing:0;font-family:Helvetica, Arial, sans-serif;color:#575757;margin:0 auto;width:100% !important;max-width:600px;text-align:left;'>
        <tbody><tr>
          <!-- Header -->
          <td class='centered header' style='padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;text-align:center;'>
            <table class='column-container' style='border-spacing:0;font-family:Helvetica, Arial, sans-serif;color:#575757;padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;width:100% !important;'>
              <tbody><tr>
                <td class='header-link' style='padding-top:17px;padding-bottom:21px;padding-right:0;padding-left:0;'>
                  
                </td>
              </tr>
              <tr>
                <td class='header-logo' style='padding-top:0;padding-right:0;padding-left:30%;padding-bottom:28px;'>
                  <img width='221' src='http://clipart.coolclips.com/480/vectors/tf05351/CoolClips_vc098730.png' class='center' alt='Stock Market Daily Update'>
                </td>
              </tr>
            </tbody></table>
          </td>
        </tr>
        <!-- Repeatable section start -->
        <tr>
          <td class='bottom-padded' style='padding-top:0;padding-right:0;padding-left:0;padding-bottom:20px;'>
            <table class='column-container section' style='border-spacing:0;font-family:Helvetica, Arial, sans-serif;color:#575757;padding-top:0;padding-right:0;padding-left:0;width:100% !important;background-color:#ffffff;background-image:none;background-repeat:repeat;background-position:left top;background-attachment:scroll;padding-bottom:3px;'>
              <tbody><tr>
                <td class='full-width-image section-main-img' style='padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;'>
                  <a href='' target='_blank'> <img src='https://www.bitdegree.org/storage/course-image/stock-market-predictions.png' alt='Python daily stock market news' width='600' style='border-width:0;width:100%;height:auto;vertical-align:middle;'></a>
                </td>
              </tr>
              <tr>
                <td class='side-padded' style='padding-top:0;padding-bottom:0;padding-left:22px;padding-right:22px;'>
                  <table class='column-container' style='border-spacing:0;font-family:Helvetica, Arial, sans-serif;color:#575757;padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;width:100% !important;'>
                    <tbody><tr>
                      <td class='section-label' style='padding-top:0;padding-right:0;padding-left:0;padding-bottom:22px;'>
                        <table class='section-label-wrapper' style='border-spacing:0;font-family:Helvetica, Arial, sans-serif;color:#575757;width:auto !important;'>
                          <tbody><tr>
                            <td class='section-label-btn-orange' style='padding-bottom:0;padding-top:1px;padding-left:10px;padding-right:10px;font-size:11px;line-height:24px;text-transform:uppercase;vertical-align:middle;font-weight:bold;color:#ee4c23;background-color:#e9f1f2;background-image:none;background-repeat:repeat;background-position:left top;background-attachment:scroll;'>
                              Exclusive Article
                            </td>
                          </tr>
                        </tbody></table>
                      </td>
                    </tr>
                    <tr>
                      <td class='section-title' style='padding-top:0;padding-right:0;padding-left:0;padding-bottom:8px;font-family:'Josefin Sans', Arial, Helvetica, sans-serif;font-weight:bold;font-size:26px;line-height:32px;color:#212121;'>
                        The standard Lorem Ipsum passage
                      </td>
                    </tr>
                    <tr>
                      <td class='section-descr' style='padding-top:0;padding-right:0;padding-left:0;padding-bottom:10px;'>
                        <p style='margin:0;margin-bottom:10px;font-size:14px;line-height:22px;'> Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum</p>
                      </td>
                    </tr>
                    <tr>
                      <td class='full-width-image section-img' style='padding-top:0;padding-right:0;padding-left:0;padding-bottom:21px;'>
                        <img src='https://images.wsj.net/im-102519?width=620&size=1.5' alt='Monochrome Seamless Patterns Preview' width='600' style='border-width:0;width:100%;height:auto;vertical-align:middle;'>
                      </td>
                    </tr>
                    <tr>
                      <td class='section-descr' style='padding-top:0;padding-right:0;padding-left:0;padding-bottom:10px;'>
                        <p style='margin:0;margin-bottom:10px;font-size:14px;line-height:22px;'>
                          Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.
                        </p>
                      </td>
                    </tr>
                    <tr>
                      <td class='section-download' style='padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;'>
                        <div>
                          <!--[if mso]>
                          <v:rect xmlns:v='urn:schemas-microsoft-com:vml' href='http://' stroke='f' fillcolor='#556270' style='height:40px;v-text-anchor:middle;width:200px;'>
                            
                            <center>
                              <![endif]-->
                          <!--[if mso]>
                        </center>
                      </v:rect>
                      <![endif]-->
                        </div>
                      </td>
                    </tr>
                  </tbody></table>
                </td>
              </tr>
            </tbody></table>
          </td>
        </tr>
        <!-- Repeatable section end -->

        <!-- Socials -->
        <tr>
          <td style='padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;'>
            <table class='column-container' style='border-spacing:0;font-family:Helvetica, Arial, sans-serif;color:#575757;padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;width:100% !important;'>
              <tbody><tr>
                <td class='social-links side-padded' style='padding-left:22px;padding-right:22px;padding-top:16px;padding-bottom:14px;background-color:#ffffff;background-image:none;background-repeat:repeat;background-position:left top;background-attachment:scroll;text-align:center;'>
                  <a href='https://twitter.com/' class='social-item tw' style='text-decoration:none;padding-left:10px;padding-right:10px;text-transform:uppercase;font-size:13px;line-height:21px;font-weight:bold;letter-spacing:1px;color:#50abdf;' target='_blank'>Twitter</a>
                    <a href='https://www.facebook.com/' class='social-item fb' style='text-decoration:none;padding-left:10px;padding-right:10px;text-transform:uppercase;font-size:13px;line-height:21px;font-weight:bold;letter-spacing:1px;color:#3a5899;' target='_blank'>Facebook</a>
                    <a href='https://www.facebook.com/' class='social-item fb' style='text-decoration:none;padding-left:10px;padding-right:10px;text-transform:uppercase;font-size:13px;line-height:21px;font-weight:bold;letter-spacing:1px;color:#3a5899;' target='_blank'>LinkedIn</a>
                  <a href='https://plus.google.com/u/0/' class='social-item go' style='text-decoration:none;padding-left:10px;padding-right:10px;text-transform:uppercase;font-size:13px;line-height:21px;font-weight:bold;letter-spacing:1px;color:#d9453d;' target='_blank'>Google+</a>
                  <a href='https://ru.pinterest.com/' class='social-item vk' style='text-decoration:none;padding-left:10px;padding-right:10px;text-transform:uppercase;font-size:13px;line-height:21px;font-weight:bold;letter-spacing:1px;color:#bd081c;' target='_blank'>Pinterest</a>
                </td>
              </tr>
            </tbody></table>
          </td>
        </tr>
        <tr>
          <!-- Unsubscribe -->
          <td class='unsubscribe side-padded' style='padding-left:22px;padding-right:22px;padding-top:24px;padding-bottom:30px;font-size:12px;line-height:19px;text-align:center;color:#a7a8a9;'>
            This email was sent to you by Python Application. Please contact your admin in case you no longer want to recieve these emails 
          </td>
        </tr>
      </tbody></table>
      <!--[if (gte mso 9)|(IE)]>
        </td>
      </tr>
    </table>
    <![endif]-->
    </div>
  </center>


</body></html>



"""

# %%
# Create a multipart message and set headers
message = MIMEMultipart("alternative")
message["From"] = sender_email
message["To"] = receiver_email
message["Subject"] = subject
message["Bcc"] = receiver_email  # Recommended for mass emails

# body = """\
# <html>
#   <body>
#     <p>Hi,<br>
#        How are you?<br>
#        <a href="http://www.realpython.com">Real Python</a> 
#        has many great tutorials.
#     </p>
#   </body>
# </html>
# """

# Add body to email
message.attach(MIMEText(body, "html"))

filename = "document.pdf"  # In same directory as script

# Open PDF file in binary mode
with open(filename, "rb") as attachment:
    # Add file as application/octet-stream
    # Email client can usually download this automatically as attachment
    part = MIMEBase("application", "octet-stream")
    part.set_payload(attachment.read())

# Encode file in ASCII characters to send by email    
encoders.encode_base64(part)

# Add header as key/value pair to attachment part
part.add_header(
    "Content-Disposition",
    f"attachment; filename= {filename}",
)

# Add attachment to message and convert message to string
message.attach(part)
text = message.as_string()

# Log in to server using secure context and send email
context = ssl.create_default_context()
with smtplib.SMTP_SSL("smtp.gmail.com", 465, context=context) as server:
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, text)
